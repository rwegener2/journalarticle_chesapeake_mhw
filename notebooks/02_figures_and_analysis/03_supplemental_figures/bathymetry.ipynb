# %% [markdown]
# # Bathymetry
#
# - Goal: quantify the extent to which bathymetry in CBay is related to the MHW Stats.
# - Data source: bathymetry downloaded from [NOAA NCEI](https://www.ncei.noaa.gov/access/metadata/landing-page/bin/iso?id=gov.noaa.ngdc.mgg.dem:chesapeake_bay_M130_2017)

# %%
import os
from pathlib import Path

import rasterio
from rasterio.enums import Resampling
import xarray as xr
import rioxarray as rio
import matplotlib.pyplot as plt

# %%
REPO_ROOT = Path('/Users/rwegener/repos/chesapeake_mhw')

# %% [markdown]
# ## Converting the netcdf to tif
#
# Followed [this great article](https://help.marine.copernicus.eu/en/articles/5029956-how-to-convert-netcdf-to-geotiff). Interesting to notice that the gdal version requires manually specified flags to work.

# %%
bath = xr.open_dataset(
    REPO_ROOT / 'data_archive/using/chesapeake_bay_M130_2017_bathymetry.nc'
)
z = bath['z']

# %%
z.rio.set_spatial_dims(x_dim='x', y_dim='y', inplace=True)
z.rio.write_crs("epsg:4326", inplace=True)
# Out:
# <xarray.DataArray 'z' (y: 31321, x: 19657)>
# [615676897 values with dtype=float32]
# Coordinates:
#   * x             (x) float64 -77.43 -77.43 -77.43 ... -75.61 -75.61 -75.61
#   * y             (y) float64 36.72 36.72 36.72 36.72 ... 39.62 39.62 39.62
#     grid_mapping  int64 0
# Attributes:
#     long_name:     z
#     actual_range:  [-54.29999924   0.        ]
#     units:         meters

# %%
z.attrs = {}

# %%
# z.rio.to_raster(
#     REPO_ROOT / 'data_archive/using/chesapeake_bay_M130_2017_bathymetry.tif'
# )

# %% [markdown]
# #### Checking Output

# %%
with rasterio.open(REPO_ROOT / 'data_archive/using/chesapeake_bay_M130_2017_bathymetry.nc') as src:
    z_raw = src.read()

plt.imshow(z_raw[0])

# %% [markdown]
# ## Resampling to the geopolar grids
#
# `rioxarray` has a `reproject_match()` method that turns out to be mighty helpful. [a mostly-code example here](https://corteva.github.io/rioxarray/stable/examples/reproject_match.html)
#
# Works smoothy, but it looks like something underneath doesn't like the the georeferencing when I try to change the resampling method from `nearest` to `bilinear`. (maybe it's from mixing a .tif with a .nc?). Based on [this quick descriptive article from ESRI](https://support.esri.com/en/technical-article/000005606) it sounds like nearest makes the most sense for categorical data and I should actually try to use `bilinear`. **circle back**
#
# - [resample_match docs](https://corteva.github.io/rioxarray/stable/rioxarray.html#rioxarray.raster_array.RasterArray.reproject_match)
# - seems like the error comes up whenever a Resample method is specified, even if `nearest` is specified

# %%
# Open mhw outputs  for reference coordinates
avg_dur = xr.open_dataset(
    REPO_ROOT / 'data_archive/processed' / 'mhw_average_characteristics.nc'
).avg_duration
avg_dur.rio.write_crs("epsg:4326", inplace=True)
# Out:
# <xarray.DataArray 'avg_duration' (latitude: 65, longitude: 40)>
# [2600 values with dtype=float64]
# Coordinates:
#   * latitude     (latitude) float32 36.78 36.83 36.88 ... 39.88 39.92 39.97
#   * longitude    (longitude) float32 -77.47 -77.43 -77.38 ... -75.57 -75.53
#     spatial_ref  int64 0
# Attributes:
#     source:           NOAA Geopolar
#     unit:             # of days
#     description:      The 'duration' statistic reported from EJO's MHW code f...
#     processing_date:  2025-01-18

# %%
avg_dur.rio.crs
# Out:
# CRS.from_epsg(4326)

# %%
ds = xr.open_dataset(REPO_ROOT / 'data/01_raw/L4_GHRSST-SSTfnd-Geo_Polar_Blended_Night-GLOB-v02.0-fv01.0_CB_20030101_20231231.nc')
geopolar = ds.analysed_sst
geopolar.rio.write_crs("epsg:4326", inplace=True)
# Out:
# <xarray.DataArray 'analysed_sst' (time: 7663, lat: 65, lon: 40)>
# [19923800 values with dtype=float32]
# Coordinates:
#   * time         (time) datetime64[ns] 2003-01-01T12:00:00 ... 2023-12-31T12:...
#   * lat          (lat) float32 36.78 36.83 36.88 36.92 ... 39.88 39.92 39.97
#   * lon          (lon) float32 -77.47 -77.43 -77.38 ... -75.62 -75.57 -75.53
#     spatial_ref  int64 0
# Attributes:
#     long_name:      analysed sea surface temperature
#     standard_name:  sea_surface_foundation_temperature
#     units:          kelvin
#     valid_min:      -200
#     valid_max:      4000
#     reference:      Fieguth,P.W. et al. "Mapping Mediterranean altimeter data...
#     source:         STAR-ACSPO_GAC, STAR-ACSPO_H-8, STAR-Geo_SST, UKMO-OSTIA
#     comment:        Analysed SST for each ocean grid point

# %%
z_reproj = z.rio.reproject_match(geopolar, method=Resampling.nearest)  
# , method=Resampling.average)
# Out:
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 z_reproj = z.rio.reproject_match(geopolar, method=Resampling.nearest)
#       2 # , method=Resampling.average)
#
# File ~/miniconda3/envs/chesapeake_mhw/lib/python3.11/site-packages/rioxarray/raster_array.py:554, in RasterArray.reproject_match(self, match_data_array, resampling, **reproject_kwargs)
#     520 def reproject_match(
#     521     self,
#     522     match_data_array: Union[xarray.DataArray, xarray.Dataset],
#     523     resampling: Resampling = Resampling.nearest,
#     524     **reproject_kwargs,
#     525 ) -> xarray.DataArray:
#     526     """
#     527     Reproject a DataArray object to match the resolution, projection,
#     528     and region of another DataArray.
#    (...)
#     552         match_data_array.
#     553     """
# --> 554     reprojected_data_array = self.reproject(
#     555         match_data_array.rio.crs,
#     556         transform=match_data_array.rio.transform(recalc=True),
#     557         shape=match_data_array.rio.shape,
#     558         resampling=resampling,
#     559         **reproject_kwargs,
#     560     )
#     561     # hack to resolve: https://github.com/corteva/rioxarray/issues/298
#     562     # may be resolved in the future by flexible indexes:
#     563     # https://github.com/pydata/xarray/pull/4489#issuecomment-831809607
#     564     x_attrs = reprojected_data_array[reprojected_data_array.rio.x_dim].attrs.copy()
#
# File ~/miniconda3/envs/chesapeake_mhw/lib/python3.11/site-packages/rioxarray/raster_array.py:458, in RasterArray.reproject(self, dst_crs, resolution, shape, transform, resampling, nodata, **kwargs)
#     454 dst_data = self._create_dst_data(dst_height, dst_width)
#     456 dst_nodata = self._get_dst_nodata(nodata)
# --> 458 rasterio.warp.reproject(
#     459     source=self._obj.values,
#     460     destination=dst_data,
#     461     src_transform=src_affine,
#     462     src_crs=self.crs,
#     463     src_nodata=self.nodata,
#     464     dst_transform=dst_affine,
#     465     dst_crs=dst_crs,
#     466     dst_nodata=dst_nodata,
#     467     resampling=resampling,
#     468     **kwargs,
#     469 )
#     470 # add necessary attributes
#     471 new_attrs = _generate_attrs(self._obj, dst_nodata)
#
# File ~/miniconda3/envs/chesapeake_mhw/lib/python3.11/site-packages/rasterio/env.py:394, in ensure_env.<locals>.wrapper(*args, **kwds)
#     392 else:
#     393     with Env.from_defaults():
# --> 394         return f(*args, **kwds)
#
# File ~/miniconda3/envs/chesapeake_mhw/lib/python3.11/site-packages/rasterio/warp.py:344, in reproject(source, destination, src_transform, gcps, rpcs, src_crs, src_nodata, dst_transform, dst_crs, dst_nodata, dst_resolution, src_alpha, dst_alpha, resampling, num_threads, init_dest_nodata, warp_mem_limit, **kwargs)
#     340         destination = np.empty((int(dst_count), int(dst_height), int(dst_width)),
#     341                                dtype=source.dtype)
#     343 # Call the function in our extension module.
# --> 344 _reproject(
#     345     source, destination, src_transform=src_transform, gcps=gcps, rpcs=rpcs,
#     346     src_crs=src_crs, src_nodata=src_nodata, dst_transform=dst_transform,
#     347     dst_crs=dst_crs, dst_nodata=dst_nodata, dst_alpha=dst_alpha,
#     348     src_alpha=src_alpha, resampling=resampling,
#     349     init_dest_nodata=init_dest_nodata, num_threads=num_threads,
#     350     warp_mem_limit=warp_mem_limit, **kwargs)
#     352 return destination, dst_transform
#
# File rasterio/_warp.pyx:516, in rasterio._warp._reproject()
#
# File rasterio/_warp.pyx:488, in rasterio._warp._reproject()
#
# File rasterio/_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# CPLE_AppDefinedError: Unable to compute a 0 based transformation between pixel/line and georeferenced coordinates for MEM:::DATAPOINTER=140251253178368,PIXELS=19657,LINES=31321,BANDS=1,DATATYPE=Float32.

# %%
z_reproj = z_reproj.rename({'x': 'longitude','y': 'latitude'})

# %%
z_reproj.plot()

# %%
z_reproj.attrs = {'Source': 'chesapeake_bay_M130_2017_bathymetry.nc', 
                  'Note': 'resampled to the grid of the geopolar data'}

z_reproj.to_dataset(name='depth').to_netcdf('/Users/rwegener/repos/mhw_ocetrac_census/data/chesapeake_bay_2017_bathymetry_resampled_geopolargrids.nc')

# %% [markdown]
# #### Alternate method for resampling: geowombat (not working)
#
# - [docs page](https://pygis.io/docs/e_raster_resample.html)
#
# Seemed hopefully but abandoned due to a mystery error. Says the CRS is not set. I tried specifying and resaving the netcdf, but now that I'm typing I wonder if because setting the crs happens in rio it doesn't get written unless I write to a raster...
#
# That worked :tada: but it looks like the package versions may be out of sync? There is a rasterio error now that looks internal to the package 😢

# %%
geopolar.rio.to_raster('../data/SST-geopolar-chesapeake/SST_geopolar_chesapeake.tif')

# %%
import geowombat as gw
import matplotlib.pyplot as plt
fig, ax = plt.subplots(dpi=200)


LS = "../data/SST-geopolar-chesapeake/SST_geopolar_chesapeake.tif"
precip = "../data/chesapeake_bay_M130_2017_bathymetry.tif"

with gw.config.update(ref_image=LS):
    with gw.open(precip, resampling="bilinear", nodata=-9999) as src:
        print(src)
        ax.imshow(src.data[0])
        
        # to write out simply:
        # src.gw.save(
        #     "../temp/precip_20200601_30m.tif",
        #     overwrite=True,
        # )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [20], in <cell line: 9>()
#       7 precip = "../data/chesapeake_bay_M130_2017_bathymetry.tif"
#       9 with gw.config.update(ref_image=LS):
# ---> 10     with gw.open(precip, resampling="bilinear", nodata=-9999) as src:
#      11         print(src)
#      12         ax.imshow(src.data[0])
#
# File ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp/lib/python3.10/site-packages/geowombat/core/api.py:512, in open.__init__(self, filename, band_names, time_names, stack_dim, bounds, bounds_by, resampling, persist_filenames, netcdf_vars, mosaic, overlap, nodata, dtype, num_workers, **kwargs)
#     509             w = src.block_window(1, 0, 0)
#     510             kwargs['chunks'] = (band_chunks, w.height, w.width)
# --> 512     self.data = warp_open(
#     513         filename,
#     514         band_names=band_names,
#     515         resampling=resampling,
#     516         dtype=dtype,
#     517         netcdf_vars=netcdf_vars,
#     518         nodata=nodata,
#     519         **kwargs
#     520     )
#     522 else:
#     523     if 'chunks' in kwargs and not isinstance(kwargs['chunks'], dict):
#
# File ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp/lib/python3.10/site-packages/geowombat/backends/xarray_.py:256, in warp_open(filename, band_names, resampling, dtype, netcdf_vars, nodata, return_windows, warp_mem_limit, num_threads, tap, **kwargs)
#     253 ref_kwargs_netcdf_stack['bounds_by'] = 'union'
#     254 del ref_kwargs_netcdf_stack['tap']
# --> 256 ref_kwargs = _check_config_globals(filename, 'reference', ref_kwargs)
#     258 filenames = None
#     260 # Create a list of variables to open
#
# File ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp/lib/python3.10/site-packages/geowombat/backends/xarray_.py:83, in _check_config_globals(filenames, bounds_by, ref_kwargs)
#      78 if config['ref_image']:
#      80     if isinstance(config['ref_image'], str) and os.path.isfile(config['ref_image']):
#      81
#      82         # Get the metadata from the reference image
# ---> 83         ref_meta = get_ref_image_meta(config['ref_image'])
#      85         ref_kwargs['bounds'] = ref_meta.bounds
#      86         ref_kwargs['crs'] = ref_meta.crs
#
# File ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp/lib/python3.10/site-packages/geowombat/backends/rasterio_.py:795, in get_ref_image_meta(filename)
#     785 """Gets warping information from a reference image
#     786
#     787 Args:
#    (...)
#     791     ``collections.namedtuple``
#     792 """
#     793 WarpInfo = namedtuple('WarpInfo', 'bounds crs res')
# --> 795 src_crs = check_file_crs(filename)
#     797 with rio.open(filename) as src:
#     798     bounds = src.bounds
#
# File ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp/lib/python3.10/site-packages/geowombat/backends/rasterio_.py:509, in check_file_crs(filename)
#     506     with rio.open(filename) as src:
#     507         src_crs = check_src_crs(src)
# --> 509 return check_crs(src_crs)
#
# File ~/.pyenv/versions/miniconda3-4.7.12/envs/sarp/lib/python3.10/site-packages/geowombat/backends/rasterio_.py:460, in check_crs(crs)
#     458 with warnings.catch_warnings():
#     459     warnings.simplefilter('ignore', UserWarning)
# --> 460     if isinstance(crs, (CRS, rio.CRS)):
#     461         dst_crs = CRS.from_wkt(crs.to_wkt())
#     462     elif isinstance(crs, (int, np.number)):
#
# AttributeError: module 'rasterio' has no attribute 'CRS'

# %% [markdown]
# ## Correlation Between Stats and Bathymetry

# %%
# remove all the cells where we don't have bathymetry
avg_dur = avg_dur.where(~z_reproj.isnull())

# %%
avg_dur = avg_dur.dropna(dim='latitude', how='all').dropna(dim='longitude', how='all')
z_reproj = z_reproj.dropna(dim='latitude', how='all').dropna(dim='longitude', how='all')

# %%
fig, axs = plt.subplots(1, 2)
avg_dur.plot(ax=axs[0])
z_reproj.plot(ax=axs[1])

# %%
avg_dur = avg_dur.assign_coords({"var": 'avg_dur'})
z_reproj = z_reproj.assign_coords({"var": 'z_reproj'})

# %%
z_reproj = z_reproj.drop('var')

# %%
combined_ds = xr.merge([avg_dur, z_reproj])

# %%
xr.plot.scatter(combined_ds, x='avg_duration', y='z')

# %% [markdown]
# Conclusions:
# - no clear relationship. not that surprised just based on eyeing up the two rasters
# - it makes some sense to me that the over all depth isn't what matters but that it would really be the mixed layer. I took another stab at finding some mixed layer info. I think its possible some is hidden in the operational now/forecasts of the bay, but even if I were to get those it I wouldn't be able to do more than check a huntch (I doubt I'd be able to get data, form a real climatology, and analyze it be the 8th)
# - Next: transitioning to buoy data for riverine validation

# %%
# open and extract dataarray
avg_int = xr.open_dataset(os.path.join(stats_dir, 'average_max_intensity_CBay_geopolar.nc'))
avg_int = avg_int.avg_max_intensity
# remove all the cells where we don't have bathymetry
avg_int = avg_int.where(~z_reproj.isnull())

# %%
avg_int = avg_int.dropna(dim='latitude', how='all').dropna(dim='longitude', how='all')

# %%
fig, axs = plt.subplots(1, 2)
avg_int.plot(ax=axs[0])
z_reproj.plot(ax=axs[1])

# %%
avg_int = avg_int.assign_coords({"var": 'avg_dur'})

# %%
combined_ds = xr.merge([avg_int, z_reproj])

# %%
xr.plot.scatter(combined_ds, x='avg_max_intensity', y='z')
