# %% [markdown]
# # Co-locating Temperature Anomaly Values between CBP Monitoring Stations and Satellite SST

# %% [markdown]
# ## Notebook Overview
# ### Tasks
# - Select satellite SST and SST anomaly values for each location and date in which there is an in situ observation from the Chesapeake Bay Program
# - Save two csvs of the results: one csv for in situ and satellite SSTs and a second csv for the in situ and satellite SST anomalies

# %% [markdown]
# This script creates a csv which holds the corresponding validation data points from both Chesapeake Bay Program's (CBP) Water Quality dataset and the two satellite datasets. The csv contains one row for each day and pixel in which there was a CBP validation point, and either a MUR or a Geopolar satellite pixel.
# Output: csv of temperature values that can be observed in the satellite SST datasets and the in situ CBP data

# %% [markdown]
# ## Analysis

# %%
import os
from pathlib import Path
import warnings

import xarray as xr
import pandas as pd
import numpy as np

# %%
REPO_ROOT = Path('/Users/rwegener/repos/chesapeake_mhw')
SAVE_FIGS = True

# %% [markdown]
# ## Read CBay Program In Situ Anomaly Data

# %%
# path_anom = REPO_ROOT / 'data/interim' / 'cbp_temps_selected_stations_with_climatology.csv'
path_anom = REPO_ROOT / 'data/02_interim' / 'cbp_ssta_selected_stations_with_climatology.csv'
anom_raw = pd.read_csv(path_anom, parse_dates=[1])

# %%
# path_sst = REPO_ROOT / 'data/interim' / 'cbp_stations_climatology_raw_filtered.csv'
path_sst = REPO_ROOT / 'data/02_interim' / 'cbp_sst_depthaveraged.csv'
sst_raw = pd.read_csv(path_sst, parse_dates=[1])

# %%
# anom_dates = pd.read_csv(
#     REPO_ROOT / 'data/interim' / 'climatology_station_dates.csv',
#     parse_dates=[1],
# )

# %% [markdown]
# ## Helper Functions
#
# Creating functions for repeated tasks

# %%
def extract_matching_value(matching_array):
    if matching_array.ndim == 0:
        matching_sst = matching_array
    elif matching_array.ndim == 1 and matching_array.size == 1:
        matching_sst = matching_array[0]
    else:
        matching_sst = np.nan
    return matching_sst

# %%
def get_satellite_sst(full_sst, lat, lon, time):
    '''
    For a given latitude, longitude, and time extract the SST value at that location
    in the give satellite dataset.
    :full_sst: 3D array of satellite SST from which to extract temperature values.
    Array must have dimensions called "lat", "lon", and "time".
    :lat: latitude value from the in situ dataset used to find the nearest SST pixel
    :lon: longitude value from the in situ dataset used to find the nearest SST pixel
    :time: time value from the in situ dataset to match in the SST dataset
    '''
    try:
        # time does NOT have nearest interpolation because we do not want adjacent days to
        # be selected
        time = time.strftime('%Y-%m-%d')
        matching_array = full_sst.sel(lat=lat, lon=lon, 
                                      method='nearest').sel(time=time).values
        # Check only one value is returned, allowing for multiple array size 
        # return shapes
        matching_sst = extract_matching_value(matching_array)
    except KeyError:
        # If a key error was raised the corresponding date was not found. 
        # Return nan for that sample location
        print('In situ date not found in satellite SST', time, 'at',
            lat, lon)
        matching_sst = np.nan
    return matching_sst

# %% [markdown]
# ## Initialize the output dataframe

# %%
anom_raw = anom_raw[['Station', 'Latitude', 'Longitude', 'SampleDate', 'anom_cbp']]
# wq_anom = anom_raw.copy()
# wq_anom['anom_geopolar'] = -999
# wq_anom['anom_mur'] = -999
# wq_anom['anom_ostia'] = -999

# %%
sst_raw = sst_raw[['Station', 'Latitude', 'Longitude', 'SampleDate', 'sst_cbp']]
wq_sst = sst_raw.copy()
wq_sst['geopolar'] = -999
wq_sst['mur'] = -999
wq_sst['ostia'] = -999

# %% [markdown]
# ## Extract SST value corresponding to CBP In situ observations

# %% [markdown]
# ### Geo-Polar SST

# %%
# Open raw SST
path = (
    REPO_ROOT / 'data/01_raw' / 
    'L4_GHRSST-SSTfnd-Geo_Polar_Blended_Night-GLOB-v02.0-fv01.0_CB_20030101_20231231.nc'
)
geopolar = xr.open_dataset(path).analysed_sst
# convert kelvin to celsius & update metadata
geopolar.values = geopolar.values - 273.15
geopolar.attrs.update({'units': 'celsius',})

# Open calculated climatological SST
path = REPO_ROOT / 'data/02_interim' / 'geopolar_climatology_chesapeake.nc'
geopolar_clim = xr.open_dataset(path).climatology

# %% [markdown]
# #### Compute the custom climatology
#
# Create monthly climatologies using only the dates which have corresponding observations from the CBP data.

# %%
anom_raw = anom_raw.set_index(['Station', 'SampleDate'])

# %%
# %%time

satellite = 'geopolar'

anom_raw[f'clim_{satellite}'] = -999
anom_raw[f'sst_{satellite}'] = -999
for station in anom_raw.index.get_level_values(0).unique():
    print('station:', station)
    station_df = anom_raw.loc[station]
    # latitude and longitude should be the same for each row, so pick 0th value
    lat = station_df.Latitude[0]
    lon = station_df.Longitude[0]
    # loop through months
    for month in range(1, 13):
        # compile all dates from that month
        month_obs_dates = station_df[station_df.index.month == month].index
        # extract corresponding satellite values
        month_obs = []
        for date in month_obs_dates:
            sst = geopolar.sel(lat=lat, lon=lon, method='nearest') \
                .sel(time=date.strftime('%Y-%m-%d')).values
            sst = extract_matching_value(sst)
            # save sst observation value in the dataframe
            anom_raw.loc[(station, date), f'sst_{satellite}'] = sst
            # append value to array for climatology
            month_obs.append(sst)
        # average to make mean (--> ex. january climatological value)
        mean = np.nanmean(np.array(month_obs))
        # save sst_clim to a new row (subtract later)
        for date in month_obs_dates:
            anom_raw.loc[(station, date), f'clim_{satellite}'] = mean
# Out:
# station: CB1.1
# station: CB2.1
# station: CB2.2
# station: CB3.1
# station: CB3.2
# station: CB3.3C
# station: CB4.1C
# station: CB4.2C
# station: CB4.3C
# station: CB4.4
# station: CB5.1
# station: CB5.2
# station: CB5.3
# station: CB6.2
# station: CB6.3
# station: CB6.4
# station: CB7.3
# station: CB7.3E
# station: CB7.4
# station: CB7.4N
# station: CB8.1
# station: CB8.1E
# station: EE1.1
# station: EE2.1
# station: EE2.2
# station: EE3.0
# station: EE3.1
# station: EE3.2
# station: ET2.2
# station: ET2.3
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# station: ET4.2
# station: ET5.2
# station: ET6.2
# station: ET8.1
# station: ET9.1
# station: LE2.2
# station: LE2.3
# station: LE3.6
# station: LE5.5-W
# station: RET2.2
# station: RET2.4
# station: WE4.1
# station: WE4.2
# station: WE4.3
# station: WE4.4
# station: WT3.1
# station: WT5.1
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# station: WT6.1
# station: WT8.1
# station: WT8.2
# station: WT8.3
# CPU times: user 30.3 s, sys: 763 ms, total: 31 s
# Wall time: 31.2 s
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice

# %%
# Calculate anomaly
anom_raw['anom_geopolar'] = anom_raw['sst_geopolar'] - anom_raw['clim_geopolar']

# %%
anom_raw
# Out:
#                     Latitude  Longitude  anom_cbp  clim_geopolar  \
# Station SampleDate
# CB1.1   2003-01-15  39.54794  -76.08481    -2.950       3.399167
#         2005-01-13  39.54794  -76.08481     1.450       3.399167
#         2006-01-12  39.54794  -76.08481     0.950       3.399167
#         2007-01-12  39.54794  -76.08481     1.150       3.399167
#         2008-01-17  39.54794  -76.08481     0.650       3.399167
# ...                      ...        ...       ...            ...
# WT8.3   2019-02-11  38.84250  -76.53410    -0.155       2.933501
#         2020-02-13  38.84250  -76.53410     2.945       2.933501
#         2021-02-08  38.84250  -76.53410    -0.755       2.933501
#         2022-02-09  38.84250  -76.53410    -0.905       2.933501
#         2023-02-16  38.84250  -76.53410     3.445       2.933501
#
#                     sst_geopolar  anom_geopolar
# Station SampleDate
# CB1.1   2003-01-15      1.630005      -1.769162
#         2005-01-13      3.160004      -0.239164
#         2006-01-12      3.910004       0.510836
#         2007-01-12      4.630005       1.230838
#         2008-01-17      3.709991       0.310824
# ...                          ...            ...
# WT8.3   2019-02-11      2.260010      -0.673491
#         2020-02-13      3.980011       1.046510
#         2021-02-08      3.220001       0.286500
#         2022-02-09      2.670013      -0.263487
#         2023-02-16      6.989990       4.056489
#
# [14744 rows x 6 columns]

# %% [markdown]
# #### Monthly climatology method
#
# Compute the monthly average climatology and use to compute anomaly.
#
# Note: This method was not used in the final manuscript. It was calculated to compare sensitivity of outputs to the choice of climatology.

# %%
monthly_method = False

# %%
if monthly_method:
    # Calculate monthly climatologies
    geopolar_clim_monthly = geopolar_clim.groupby('time.month').mean()
    
    # Reshape climatology array so it matches shape of sst data
    list_of_arrays = []
    for time in geopolar.time:
        list_of_arrays.append(geopolar_clim_monthly.sel(month=time.dt.month))
    geopolar_clim_monthly = xr.concat(list_of_arrays, dim=geopolar.time)
    
    # Compute anomaly values
    geopolar_anom = geopolar - geopolar_clim_monthly

# %% [markdown]
# Timing Notes
#
# Feb 1: ~22,000 rows: ~50 seconds

# %% [markdown]
# Find corresponding anomaly values

# %%
# %%time

# Create a new column of the wq dataframe containing the corresponding geopolar sst value
# wq_anom['anom_geopolar'] = wq_anom.apply(lambda x: get_satellite_sst(
#     geopolar_monthlyanom, x.Latitude, x.Longitude, 
#     x.SampleDate), axis=1)
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 7.15 µs

# %% [markdown]
# Find corresponding observed SST values

# %%
# Create a new column of the wq dataframe containing the corresponding geopolar sst value
wq_sst['geopolar'] = wq_sst.apply(lambda x: get_satellite_sst(geopolar, x.Latitude, x.Longitude, x.SampleDate), 
                                                axis=1)

# %%
# delete large data structures to save memory
# del geopolar

# %% [markdown]
# ### MUR SST

# %%
# Open raw SST
path = (
    REPO_ROOT / 'data/01_raw' / 
    'MUR-JPL-L4_GHRSST-SSTfnd-GLOB-v02.0-fv04.1-CB-20030101_20231231.nc'
)
mur = xr.open_dataset(path).analysed_sst
# convert kelvin to celsius & update metadata
mur.values = mur.values - 273.15
mur.attrs.update({'units': 'celsius',})

# Open calculated climatological SST
# path = REPO_ROOT / 'data/interim/data_cache_Dec24' / 'mur_climatology_chesapeake.nc'
path = REPO_ROOT / 'data/02_interim' / 'mur_climatology_chesapeake.nc'
mur_clim = xr.open_dataset(path).climatology

# %% [markdown]
# #### Monthly climatology method
#
# Compute the monthly average climatology and use to compute anomaly.
#
# **Note:** This method was not used in the final manuscript. It was calculated to compare sensitivity of outputs to the choice of climatology.

# %%
monthly_method = False

# %%
if monthly_method:
    # Calculate monthly climatologies
    mur_clim_monthly = mur_clim.groupby('time.month').mean()
    
    # Reshape climatology array so it matches shape of sst data
    list_of_arrays = []
    for time in mur.time:
        list_of_arrays.append(mur_clim_monthly.sel(month=time.dt.month))
        mur_clim_monthly = xr.concat(list_of_arrays, dim=mur.time)
    
    # Compute anomaly values
    mur_anom = mur - mur_clim_monthly

# %% [markdown]
# Find corresponding anomaly values

# %%
# Create a new column of the wq dataframe containing the corresponding mur sst value
# wq_anom['anom_mur'] = wq_anom.apply(lambda x: get_satellite_sst(mur_anom, x.Latitude, x.Longitude, x.SampleDate), 
#                                                 axis=1)

# %% [markdown]
# #### Compute the custom climatology
#
# Create monthly climatologies using only the dates which have corresponding observations from the CBP data.

# %%
# %%time

satellite = 'mur'

anom_raw[f'clim_{satellite}'] = -999
anom_raw[f'sst_{satellite}'] = -999
for station in anom_raw.index.get_level_values(0).unique():
    print('station:', station)
    station_df = anom_raw.loc[station]
    # latitude and longitude should be the same for each row, so pick 0th value
    lat = station_df.Latitude[0]
    lon = station_df.Longitude[0]
    # loop through months
    for month in range(1, 13):
        # compile all dates from that month
        month_obs_dates = station_df[station_df.index.month == month].index
        # extract corresponding satellite values
        month_obs = []
        for date in month_obs_dates:
            sst = mur.sel(lat=lat, lon=lon, method='nearest') \
                .sel(time=date.strftime('%Y-%m-%d')).values
            sst = extract_matching_value(sst)
            # save sst observation value in the dataframe
            anom_raw.loc[(station, date), f'sst_{satellite}'] = sst
            # append value to array for climatology
            month_obs.append(sst)
        # average to make mean (--> ex. january climatological value)
        mean = np.nanmean(np.array(month_obs))
        # save sst_clim to a new row (subtract later)
        for date in month_obs_dates:
            anom_raw.loc[(station, date), f'clim_{satellite}'] = mean
# Out:
# station: CB1.1
# station: CB2.1
# station: CB2.2
# station: CB3.1
# station: CB3.2
# station: CB3.3C
# station: CB4.1C
# station: CB4.2C
# station: CB4.3C
# station: CB4.4
# station: CB5.1
# station: CB5.2
# station: CB5.3
# station: CB6.2
# station: CB6.3
# station: CB6.4
# station: CB7.3
# station: CB7.3E
# station: CB7.4
# station: CB7.4N
# station: CB8.1
# station: CB8.1E
# station: EE1.1
# station: EE2.1
# station: EE2.2
# station: EE3.0
# station: EE3.1
# station: EE3.2
# station: ET2.2
# station: ET2.3
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# station: ET4.2
# station: ET5.2
# station: ET6.2
# station: ET8.1
# station: ET9.1
# station: LE2.2
# station: LE2.3
# station: LE3.6
# station: LE5.5-W
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# station: RET2.2
# station: RET2.4
# station: WE4.1
# station: WE4.2
# station: WE4.3
# station: WE4.4
# station: WT3.1
# station: WT5.1
# station: WT6.1
# station: WT8.1
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# station: WT8.2
# station: WT8.3
# CPU times: user 31.8 s, sys: 911 ms, total: 32.7 s
# Wall time: 33.2 s
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice
# <timed exec>:26: RuntimeWarning: Mean of empty slice

# %%
anom_raw['anom_mur'] = anom_raw['sst_mur'] - anom_raw['clim_mur']

# %%
anom_raw
# Out:
#                     Latitude  Longitude  anom_cbp  clim_geopolar  \
# Station SampleDate
# CB1.1   2003-01-15  39.54794  -76.08481    -2.950       3.399167
#         2005-01-13  39.54794  -76.08481     1.450       3.399167
#         2006-01-12  39.54794  -76.08481     0.950       3.399167
#         2007-01-12  39.54794  -76.08481     1.150       3.399167
#         2008-01-17  39.54794  -76.08481     0.650       3.399167
# ...                      ...        ...       ...            ...
# WT8.3   2019-02-11  38.84250  -76.53410    -0.155       2.933501
#         2020-02-13  38.84250  -76.53410     2.945       2.933501
#         2021-02-08  38.84250  -76.53410    -0.755       2.933501
#         2022-02-09  38.84250  -76.53410    -0.905       2.933501
#         2023-02-16  38.84250  -76.53410     3.445       2.933501
#
#                     sst_geopolar  anom_geopolar  clim_mur   sst_mur  anom_mur
# Station SampleDate
# CB1.1   2003-01-15      1.630005      -1.769162  3.876915  2.075989 -1.800926
#         2005-01-13      3.160004      -0.239164  3.876915  4.101013  0.224098
#         2006-01-12      3.910004       0.510836  3.876915  1.149994 -2.726921
#         2007-01-12      4.630005       1.230838  3.876915  6.183990  2.307076
#         2008-01-17      3.709991       0.310824  3.876915  3.701996 -0.174919
# ...                          ...            ...       ...       ...       ...
# WT8.3   2019-02-11      2.260010      -0.673491       NaN       NaN       NaN
#         2020-02-13      3.980011       1.046510       NaN       NaN       NaN
#         2021-02-08      3.220001       0.286500       NaN       NaN       NaN
#         2022-02-09      2.670013      -0.263487       NaN       NaN       NaN
#         2023-02-16      6.989990       4.056489       NaN       NaN       NaN
#
# [14744 rows x 9 columns]

# %% [markdown]
# Find corresponding observed SST values

# %%
# Create a new column of the wq dataframe containing the corresponding mur sst value
wq_sst['mur'] = wq_sst.apply(lambda x: get_satellite_sst(mur, x.Latitude, x.Longitude, x.SampleDate), 
                                                axis=1)

# %%
# delete large data structures to save memory
# del mur

# %% [markdown]
# ### OSTIA SST
#
# Note: OSTIA has lots of missing dates because OSTIA begins in 2006, while the in situ records begin in 2003.

# %%
# Open raw SST
path = (
    REPO_ROOT / 'data/01_raw' / 
    'METOFFICE-GLO-SST-L4-NRT-OBS-SST-V2_analysed_sst_77.47W-75.53W_36.78N-39.97N_2007-01-01-2023-12-31.nc'
)
ostia = xr.open_dataset(path).analysed_sst
ostia = ostia.rename({'latitude': 'lat', 'longitude': 'lon'})
# convert kelvin to celsius & update metadata
ostia.values = ostia.values - 273.15
ostia.attrs.update({'units': 'celsius',})

# Open calculated climatological SST
# path = REPO_ROOT / 'data/interim/data_cache_Dec24' / 'ostia_climatology_chesapeake.nc'
path = REPO_ROOT / 'data/02_interim' / 'ostia_climatology_chesapeake.nc'
ostia_clim = xr.open_dataset(path).climatology

# %% [markdown]
# #### Monthly climatology method
#
# Compute the monthly average climatology and use to compute anomaly.
#
# **Note:** This method was not used in the final manuscript. It was calculated to compare sensitivity of outputs to the choice of climatology.

# %%
monthly_method = False

# %%
if monthly_method:
    # Calculate monthly climatologies
    ostia_clim_monthly = ostia_clim.groupby('time.month').mean()
    
    # Reshape climatology array so it matches shape of sst data
    list_of_arrays = []
    for time in ostia.time:
        list_of_arrays.append(ostia_clim_monthly.sel(month=time.dt.month))
    ostia_clim_monthly = xr.concat(list_of_arrays, dim=ostia.time)
    
    # Compute anomaly values
    ostia_anom = ostia - ostia_clim_monthly

# %% [markdown]
# Find corresponding anomaly values

# %%
# Ensure all values are floats and none are np.ndarray
# wq_anom['anom_ostia'] = wq_anom['anom_ostia'].map(
#     lambda x: x.tolist() if isinstance(x, np.ndarray) else None
# )

# %%
# Create a new column of the wq dataframe containing the corresponding geopolar sst value
# wq_anom['anom_ostia'] = wq_anom.apply(
#     lambda x: get_satellite_sst(ostia_anom, x.Latitude, x.Longitude, 
#                                 x.SampleDate), axis=1)

# %% [markdown]
# #### Compute the custom climatology
#
# Create monthly climatologies using only the dates which have corresponding observations from the CBP data.

# %%
# %%time

satellite = 'ostia'

anom_raw[f'clim_{satellite}'] = -999
anom_raw[f'sst_{satellite}'] = -999
for station in anom_raw.index.get_level_values(0).unique():
    print('station:', station)
    station_df = anom_raw.loc[station]
    # latitude and longitude should be the same for each row, so pick 0th value
    lat = station_df.Latitude[0]
    lon = station_df.Longitude[0]
    # loop through months
    for month in range(1, 13):
        # compile all dates from that month
        month_obs_dates = station_df[station_df.index.month == month].index
        # extract corresponding satellite values
        month_obs = []
        for date in month_obs_dates:
            if date > pd.to_datetime('2006-12-31'):
                sst = ostia.sel(lat=lat, lon=lon, method='nearest') \
                    .sel(time=date.strftime('%Y-%m-%d')).values
                sst = extract_matching_value(sst)
                # save sst observation value in the dataframe
                anom_raw.loc[(station, date), f'sst_{satellite}'] = sst
                # append value to array for climatology
                month_obs.append(sst)
            else:
                anom_raw.loc[(station, date), f'sst_{satellite}'] = np.nan
        # average to make mean (--> ex. january climatological value)
        mean = np.nanmean(np.array(month_obs))
        # save sst_clim to a new row (subtract later)
        for date in month_obs_dates:
            anom_raw.loc[(station, date), f'clim_{satellite}'] = mean
# Out:
# station: CB1.1
# station: CB2.1
# station: CB2.2
# station: CB3.1
# station: CB3.2
# station: CB3.3C
# station: CB4.1C
# station: CB4.2C
# station: CB4.3C
# station: CB4.4
# station: CB5.1
# station: CB5.2
# station: CB5.3
# station: CB6.2
# station: CB6.3
# station: CB6.4
# station: CB7.3
# station: CB7.3E
# station: CB7.4
# station: CB7.4N
# station: CB8.1
# station: CB8.1E
# station: EE1.1
# station: EE2.1
# station: EE2.2
# station: EE3.0
# station: EE3.1
# station: EE3.2
# station: ET2.2
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# station: ET2.3
# station: ET4.2
# station: ET5.2
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# station: ET6.2
# station: ET8.1
# station: ET9.1
# station: LE2.2
# station: LE2.3
# station: LE3.6
# station: LE5.5-W
# station: RET2.2
# station: RET2.4
# station: WE4.1
# station: WE4.2
# station: WE4.3
# station: WE4.4
# station: WT3.1
# station: WT5.1
# station: WT6.1
# station: WT8.1
# station: WT8.2
# station: WT8.3
# CPU times: user 22.9 s, sys: 533 ms, total: 23.4 s
# Wall time: 23.8 s
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice
# <timed exec>:29: RuntimeWarning: Mean of empty slice

# %%
anom_raw['anom_ostia'] = anom_raw['sst_ostia'] - anom_raw['clim_ostia']

# %%
anom_raw
# Out:
#                     Latitude  Longitude  anom_cbp  clim_geopolar  \
# Station SampleDate
# CB1.1   2003-01-15  39.54794  -76.08481    -2.950       3.399167
#         2005-01-13  39.54794  -76.08481     1.450       3.399167
#         2006-01-12  39.54794  -76.08481     0.950       3.399167
#         2007-01-12  39.54794  -76.08481     1.150       3.399167
#         2008-01-17  39.54794  -76.08481     0.650       3.399167
# ...                      ...        ...       ...            ...
# WT8.3   2019-02-11  38.84250  -76.53410    -0.155       2.933501
#         2020-02-13  38.84250  -76.53410     2.945       2.933501
#         2021-02-08  38.84250  -76.53410    -0.755       2.933501
#         2022-02-09  38.84250  -76.53410    -0.905       2.933501
#         2023-02-16  38.84250  -76.53410     3.445       2.933501
#
#                     sst_geopolar  anom_geopolar  clim_mur   sst_mur  anom_mur  \
# Station SampleDate
# CB1.1   2003-01-15      1.630005      -1.769162  3.876915  2.075989 -1.800926
#         2005-01-13      3.160004      -0.239164  3.876915  4.101013  0.224098
#         2006-01-12      3.910004       0.510836  3.876915  1.149994 -2.726921
#         2007-01-12      4.630005       1.230838  3.876915  6.183990  2.307076
#         2008-01-17      3.709991       0.310824  3.876915  3.701996 -0.174919
# ...                          ...            ...       ...       ...       ...
# WT8.3   2019-02-11      2.260010      -0.673491       NaN       NaN       NaN
#         2020-02-13      3.980011       1.046510       NaN       NaN       NaN
#         2021-02-08      3.220001       0.286500       NaN       NaN       NaN
#         2022-02-09      2.670013      -0.263487       NaN       NaN       NaN
#         2023-02-16      6.989990       4.056489       NaN       NaN       NaN
#
#                     clim_ostia  sst_ostia  anom_ostia
# Station SampleDate
# CB1.1   2003-01-15    3.614438        NaN         NaN
#         2005-01-13    3.614438        NaN         NaN
#         2006-01-12    3.614438        NaN         NaN
#         2007-01-12    3.614438   3.609985   -0.004452
#         2008-01-17    3.614438   3.739990    0.125553
# ...                        ...        ...         ...
# WT8.3   2019-02-11    2.861764   2.290009   -0.571756
#         2020-02-13    2.861764   3.869995    1.008231
#         2021-02-08    2.861764   3.440002    0.578238
#         2022-02-09    2.861764   2.640015   -0.221750
#         2023-02-16    2.861764   7.440002    4.578238
#
# [14744 rows x 12 columns]

# %% [markdown]
# Find corresponding observed SST values

# %%
# Ensure all values are floats and none are np.ndarray
wq_sst['ostia'] = wq_sst['ostia'].map(
    lambda x: x.tolist() if isinstance(x, np.ndarray) else None
)

# %%
# Create a new column of the wq dataframe containing the corresponding geopolar sst value
wq_sst['ostia'] = wq_sst.apply(lambda x: get_satellite_sst(ostia, x.Latitude, x.Longitude, x.SampleDate), 
                                                axis=1)
# Out:
# In situ date not found in satellite SST 2006-08-07 at 38.64028 -77.22222
# In situ date not found in satellite SST 2006-09-12 at 38.64028 -77.22222
# In situ date not found in satellite SST 2006-10-10 at 38.64028 -77.22222
# In situ date not found in satellite SST 2006-08-28 at 38.3475 -77.3275
# In situ date not found in satellite SST 2006-04-11 at 38.4205 -77.3532
# In situ date not found in satellite SST 2006-05-18 at 38.4205 -77.3532
# In situ date not found in satellite SST 2006-06-15 at 38.4205 -77.3532
# In situ date not found in satellite SST 2006-07-18 at 38.4205 -77.3532
# In situ date not found in satellite SST 2006-08-09 at 38.4205 -77.3532
# In situ date not found in satellite SST 2006-09-11 at 38.4205 -77.3532
# In situ date not found in satellite SST 2006-10-25 at 38.4205 -77.3532
# In situ date not found in satellite SST 2003-01-15 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-03-12 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-04-09 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-04-23 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-05-07 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-05-21 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-06-18 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-07-09 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-07-23 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-08-06 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-08-20 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-09-17 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-09-23 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-10-08 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-11-19 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-12-18 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-02-19 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-03-17 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-04-14 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-04-28 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-05-12 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-05-26 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-06-09 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-06-24 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-07-08 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-07-21 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-08-11 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-08-25 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-09-22 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-10-14 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-11-11 at 39.54794 -76.08481
# In situ date not found in satellite SST 2004-12-08 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-01-13 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-02-16 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-03-16 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-04-06 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-04-20 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-05-12 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-05-26 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-06-15 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-06-29 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-07-13 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-07-27 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-08-10 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-08-25 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-09-14 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-10-27 at 39.54794 -76.08481
# In situ date not found in satellite SST 2005-11-17 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-01-12 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-02-09 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-03-09 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-04-06 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-04-19 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-05-10 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-05-24 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-06-07 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-06-21 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-07-13 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-07-27 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-08-16 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-08-30 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-09-20 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-10-18 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-11-15 at 39.54794 -76.08481
# In situ date not found in satellite SST 2006-12-13 at 39.54794 -76.08481
# In situ date not found in satellite SST 2003-01-15 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-03-12 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-04-09 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-04-23 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-05-07 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-05-21 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-06-18 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-07-09 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-07-23 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-08-06 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-08-20 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-09-17 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-09-23 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-10-08 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-11-19 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-12-18 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-01-14 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-02-19 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-03-17 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-04-14 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-04-28 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-05-12 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-05-26 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-06-09 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-06-24 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-07-08 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-07-21 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-08-11 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-08-25 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-09-22 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-10-14 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-11-11 at 39.44149 -76.02599
# In situ date not found in satellite SST 2004-12-08 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-01-13 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-02-17 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-03-16 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-04-06 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-04-20 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-05-12 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-05-26 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-06-15 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-06-29 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-07-13 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-07-27 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-08-10 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-08-25 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-09-14 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-10-27 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-11-17 at 39.44149 -76.02599
# In situ date not found in satellite SST 2005-12-15 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-01-12 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-02-09 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-03-09 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-04-06 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-04-19 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-05-10 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-05-24 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-06-07 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-06-21 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-07-13 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-07-27 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-08-16 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-08-30 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-09-20 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-10-18 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-11-15 at 39.44149 -76.02599
# In situ date not found in satellite SST 2006-12-13 at 39.44149 -76.02599
# In situ date not found in satellite SST 2003-01-15 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-03-12 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-04-09 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-04-23 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-05-07 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-05-21 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-06-18 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-07-09 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-07-23 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-08-06 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-08-20 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-09-17 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-09-23 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-10-08 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-11-19 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-12-18 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-01-14 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-02-19 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-03-17 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-04-14 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-04-28 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-05-12 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-05-26 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-06-09 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-06-24 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-07-08 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-07-21 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-08-11 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-08-25 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-09-22 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-10-14 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-11-11 at 39.34873 -76.17579
# In situ date not found in satellite SST 2004-12-08 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-01-13 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-02-17 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-03-16 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-04-06 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-04-20 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-05-12 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-05-26 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-06-15 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-06-29 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-07-13 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-07-27 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-08-10 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-08-25 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-09-14 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-10-27 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-11-17 at 39.34873 -76.17579
# In situ date not found in satellite SST 2005-12-15 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-01-12 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-02-09 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-03-09 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-04-06 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-04-19 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-05-10 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-05-24 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-06-07 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-06-21 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-07-13 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-07-27 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-08-16 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-08-30 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-09-20 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-10-18 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-11-15 at 39.34873 -76.17579
# In situ date not found in satellite SST 2006-12-13 at 39.34873 -76.17579
# In situ date not found in satellite SST 2003-01-15 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-02-14 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-03-12 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-04-08 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-05-07 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-05-21 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-06-18 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-07-09 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-07-23 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-08-06 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-08-20 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-09-16 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-09-23 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-10-08 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-11-18 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-12-18 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-01-14 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-02-19 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-03-17 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-04-14 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-04-28 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-05-12 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-05-26 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-06-09 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-06-24 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-07-08 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-07-21 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-08-11 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-08-25 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-09-22 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-10-14 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-11-11 at 39.2495 -76.2405
# In situ date not found in satellite SST 2004-12-08 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-01-13 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-02-17 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-03-16 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-04-06 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-04-20 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-05-12 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-05-26 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-06-15 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-06-29 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-07-13 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-07-27 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-08-10 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-08-25 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-09-14 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-10-27 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-11-15 at 39.2495 -76.2405
# In situ date not found in satellite SST 2005-12-15 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-01-12 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-02-09 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-03-09 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-04-06 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-04-19 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-05-10 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-05-24 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-06-07 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-06-21 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-07-13 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-07-27 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-08-16 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-08-30 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-09-20 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-10-18 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-11-15 at 39.2495 -76.2405
# In situ date not found in satellite SST 2006-12-13 at 39.2495 -76.2405
# In situ date not found in satellite SST 2003-01-16 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-02-14 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-03-12 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-04-08 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-05-07 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-05-21 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-06-18 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-07-09 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-07-23 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-08-06 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-08-20 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-09-16 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-09-23 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-10-08 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-11-18 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-12-17 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-01-14 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-02-18 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-03-17 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-04-14 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-04-28 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-05-12 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-05-26 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-06-09 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-06-24 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-07-08 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-07-21 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-08-11 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-08-25 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-09-22 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-10-14 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-11-10 at 39.16369 -76.30631
# In situ date not found in satellite SST 2004-12-08 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-01-12 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-02-16 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-03-16 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-04-06 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-04-20 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-05-12 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-05-26 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-06-15 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-06-29 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-07-13 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-07-27 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-08-10 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-08-25 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-09-14 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-10-27 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-11-15 at 39.16369 -76.30631
# In situ date not found in satellite SST 2005-12-15 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-01-11 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-02-08 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-03-09 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-04-06 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-04-19 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-05-10 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-05-24 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-06-07 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-06-21 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-07-13 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-07-27 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-08-16 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-08-30 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-09-20 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-10-18 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-11-15 at 39.16369 -76.30631
# In situ date not found in satellite SST 2006-12-13 at 39.16369 -76.30631
# In situ date not found in satellite SST 2003-01-16 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-02-14 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-03-12 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-04-08 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-04-22 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-05-06 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-05-20 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-06-17 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-07-08 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-07-22 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-08-05 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-08-19 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-09-16 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-09-23 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-10-07 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-11-18 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-12-17 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-01-13 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-02-18 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-03-17 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-04-13 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-04-27 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-05-11 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-05-25 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-06-08 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-06-23 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-07-07 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-07-20 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-08-10 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-08-24 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-09-21 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-10-14 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-11-10 at 38.99596 -76.35967
# In situ date not found in satellite SST 2004-12-07 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-01-12 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-02-16 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-03-15 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-04-05 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-04-19 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-05-11 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-05-25 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-06-14 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-06-28 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-07-12 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-07-26 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-08-09 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-08-24 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-09-13 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-10-27 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-11-15 at 38.99596 -76.35967
# In situ date not found in satellite SST 2005-12-14 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-01-11 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-02-08 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-03-08 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-04-06 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-04-19 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-05-09 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-05-23 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-06-06 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-06-20 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-07-12 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-07-26 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-08-15 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-08-29 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-09-19 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-10-17 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-11-15 at 38.99596 -76.35967
# In situ date not found in satellite SST 2006-12-12 at 38.99596 -76.35967
# In situ date not found in satellite SST 2003-03-12 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-04-22 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-05-06 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-05-20 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-06-17 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-07-08 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-07-22 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-08-05 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-08-19 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-09-16 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-10-07 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-03-17 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-04-13 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-04-27 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-05-11 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-05-25 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-06-08 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-06-23 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-07-07 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-07-20 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-08-10 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-08-24 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-09-21 at 39.00412 -76.34517
# In situ date not found in satellite SST 2004-10-14 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-03-15 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-04-05 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-04-19 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-05-11 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-05-25 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-06-14 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-06-28 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-07-12 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-07-26 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-08-09 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-08-24 at 39.00412 -76.34517
# In situ date not found in satellite SST 2005-09-13 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-03-08 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-04-06 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-04-19 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-05-09 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-05-23 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-06-06 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-06-20 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-07-12 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-07-26 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-08-15 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-08-29 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-09-19 at 39.00412 -76.34517
# In situ date not found in satellite SST 2006-10-17 at 39.00412 -76.34517
# In situ date not found in satellite SST 2003-03-12 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-04-22 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-05-06 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-05-20 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-06-17 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-07-08 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-07-22 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-08-05 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-08-19 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-09-16 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-10-07 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-03-17 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-04-13 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-04-27 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-05-11 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-05-25 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-06-08 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-06-23 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-07-07 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-07-20 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-08-10 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-08-24 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-09-21 at 39.00462 -76.3881
# In situ date not found in satellite SST 2004-10-14 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-03-15 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-04-05 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-04-19 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-05-11 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-05-25 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-06-14 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-06-28 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-07-12 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-07-26 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-08-09 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-08-24 at 39.00462 -76.3881
# In situ date not found in satellite SST 2005-09-13 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-03-08 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-04-06 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-04-19 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-05-09 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-05-23 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-06-06 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-06-20 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-07-12 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-07-26 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-08-15 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-08-29 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-09-19 at 39.00462 -76.3881
# In situ date not found in satellite SST 2006-10-17 at 39.00462 -76.3881
# In situ date not found in satellite SST 2003-01-14 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-02-14 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-03-11 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-04-08 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-04-22 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-05-06 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-05-20 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-06-17 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-07-08 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-07-22 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-08-05 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-08-19 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-09-23 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-10-07 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-11-18 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-12-17 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-01-13 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-02-18 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-03-16 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-04-13 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-04-27 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-05-11 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-05-25 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-06-08 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-06-23 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-07-07 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-07-20 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-08-10 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-08-24 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-09-21 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-10-13 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-11-10 at 38.82593 -76.39945
# In situ date not found in satellite SST 2004-12-07 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-01-12 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-02-16 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-03-15 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-04-05 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-04-19 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-05-11 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-05-25 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-06-14 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-06-28 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-07-12 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-07-26 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-08-09 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-08-24 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-09-13 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-10-26 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-11-15 at 38.82593 -76.39945
# In situ date not found in satellite SST 2005-12-14 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-01-11 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-02-08 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-03-08 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-04-06 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-04-18 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-05-09 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-05-23 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-06-06 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-06-20 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-07-12 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-07-26 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-08-15 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-08-29 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-09-19 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-10-17 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-11-15 at 38.82593 -76.39945
# In situ date not found in satellite SST 2006-12-12 at 38.82593 -76.39945
# In situ date not found in satellite SST 2003-03-11 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-04-22 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-05-06 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-05-20 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-06-17 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-07-08 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-07-22 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-08-05 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-08-19 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-09-16 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-10-07 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-03-16 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-04-13 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-04-27 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-05-11 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-05-25 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-06-08 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-06-23 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-07-07 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-07-20 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-08-10 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-08-24 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-09-21 at 38.81809 -76.37144
# In situ date not found in satellite SST 2004-10-13 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-03-15 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-04-05 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-04-19 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-05-11 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-05-25 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-06-14 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-06-28 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-07-12 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-07-26 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-08-09 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-08-24 at 38.81809 -76.37144
# In situ date not found in satellite SST 2005-09-13 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-03-08 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-04-06 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-04-18 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-05-09 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-05-23 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-06-06 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-06-20 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-07-12 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-07-26 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-08-15 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-08-29 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-09-19 at 38.81809 -76.37144
# In situ date not found in satellite SST 2006-10-17 at 38.81809 -76.37144
# In situ date not found in satellite SST 2003-03-11 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-04-22 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-05-06 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-05-20 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-06-17 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-07-08 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-07-22 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-08-05 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-08-19 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-09-16 at 38.81498 -76.46272
# In situ date not found in satellite SST 2003-10-07 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-03-16 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-04-13 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-04-27 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-05-11 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-05-25 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-06-08 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-06-23 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-07-07 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-07-20 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-08-10 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-08-24 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-09-21 at 38.81498 -76.46272
# In situ date not found in satellite SST 2004-10-13 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-03-15 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-04-05 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-04-19 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-05-11 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-05-25 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-06-14 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-06-28 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-07-12 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-07-26 at 38.81498 -76.46272
# In situ date not found in satellite SST 2005-08-09 at 38.81498 -76.46272
# ...
# In situ date not found in satellite SST 2003-09-29 at 39.41072 -76.24762
# In situ date not found in satellite SST 2003-10-20 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-04-08 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-05-27 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-06-15 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-07-12 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-08-17 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-09-02 at 39.41072 -76.24762
# In situ date not found in satellite SST 2004-10-05 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-04-11 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-05-03 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-06-06 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-07-07 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-08-01 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-09-01 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-10-04 at 39.41072 -76.24762
# In situ date not found in satellite SST 2005-04-11 at 39.462 -76.2407
# In situ date not found in satellite SST 2006-04-13 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-04-27 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-05-11 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-05-25 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-06-08 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-06-22 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-07-20 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-08-03 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-08-31 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-09-14 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-09-28 at 39.3717 -76.06252
# In situ date not found in satellite SST 2006-10-12 at 39.3717 -76.06252
# In situ date not found in satellite SST 2005-03-10 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-04-11 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-05-09 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-06-06 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-07-05 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-08-01 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-09-09 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-10-03 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-11-15 at 37.22727 -76.4228
# In situ date not found in satellite SST 2005-03-10 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-03-16 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-03-30 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-04-14 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-04-27 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-05-09 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-05-10 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-05-25 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-06-01 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-06-06 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-06-08 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-06-16 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-06-22 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-07-06 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-07-13 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-07-20 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-07-27 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-08-01 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-08-03 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-08-10 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-08-17 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-09-07 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-09-09 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-09-14 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-09-21 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-09-28 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-10-03 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-10-05 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-10-12 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-10-19 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-10-26 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-11-01 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-11-09 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-11-15 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-11-16 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-11-28 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-12-07 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-12-19 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-01-04 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-02-01 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-02-15 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-03-01 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-03-23 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-04-04 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-04-19 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-05-03 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-05-17 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-05-31 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-06-14 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-06-29 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-07-12 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-07-20 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-07-26 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-08-09 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-08-16 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-08-23 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-08-30 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-09-06 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-09-13 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-09-27 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-10-04 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-10-11 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-10-18 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-11-20 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-12-06 at 37.24828 -76.49651
# In situ date not found in satellite SST 2006-12-18 at 37.24828 -76.49651
# In situ date not found in satellite SST 2005-03-10 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-03-16 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-03-30 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-04-11 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-04-14 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-04-27 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-05-09 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-05-10 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-05-25 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-06-01 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-06-06 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-06-08 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-06-16 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-06-22 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-06-29 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-07-05 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-07-06 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-07-13 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-07-20 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-07-27 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-08-01 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-08-03 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-08-10 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-08-17 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-08-24 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-08-31 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-09-07 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-09-09 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-09-14 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-09-21 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-10-03 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-10-05 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-10-12 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-10-19 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-10-26 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-11-01 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-11-09 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-11-15 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-11-16 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-12-05 at 37.24432 -76.5243
# In situ date not found in satellite SST 2005-03-10 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-05-09 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-06-06 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-07-05 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-08-01 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-09-09 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-10-03 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-11-15 at 37.29657 -76.56287
# In situ date not found in satellite SST 2005-05-10 at 37.30047 -76.60819
# In situ date not found in satellite SST 2005-06-07 at 37.30047 -76.60819
# In situ date not found in satellite SST 2005-07-06 at 37.30047 -76.60819
# In situ date not found in satellite SST 2005-08-02 at 37.30047 -76.60819
# In situ date not found in satellite SST 2005-09-09 at 37.30047 -76.60819
# In situ date not found in satellite SST 2005-10-04 at 37.30047 -76.60819
# In situ date not found in satellite SST 2005-01-12 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-01-24 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-02-09 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-02-22 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-04-12 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-04-14 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-04-27 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-05-10 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-05-25 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-06-08 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-06-22 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-07-06 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-07-20 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-08-02 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-08-03 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-08-10 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-09-07 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-09-09 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-09-21 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-10-04 at 37.34708 -76.61164999999998
# In situ date not found in satellite SST 2005-10-05 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-10-12 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-10-19 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-11-01 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-11-16 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-02-01 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-03-01 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-05-03 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-05-17 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-05-31 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-06-14 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-06-29 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-07-12 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-07-26 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-08-09 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-08-23 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-09-06 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-09-13 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-09-27 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-10-11 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-10-18 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-11-20 at 37.34708 -76.61165
# In situ date not found in satellite SST 2006-12-06 at 37.34708 -76.61165
# In situ date not found in satellite SST 2005-05-10 at 37.41742 -76.70888
# In situ date not found in satellite SST 2005-06-07 at 37.41742 -76.70888
# In situ date not found in satellite SST 2005-07-06 at 37.41742 -76.70888
# In situ date not found in satellite SST 2005-08-02 at 37.41742 -76.70888
# In situ date not found in satellite SST 2005-09-09 at 37.41742 -76.70888
# In situ date not found in satellite SST 2005-10-04 at 37.41742 -76.70888
# In situ date not found in satellite SST 2005-04-12 at 37.48865 -76.74903
# In situ date not found in satellite SST 2005-05-10 at 37.48865 -76.74903
# In situ date not found in satellite SST 2005-07-06 at 37.48865 -76.74903
# In situ date not found in satellite SST 2005-08-02 at 37.48865 -76.74903
# In situ date not found in satellite SST 2005-09-09 at 37.48865 -76.74903
# In situ date not found in satellite SST 2005-10-04 at 37.48865 -76.74903
# In situ date not found in satellite SST 2005-04-12 at 37.50465 -76.79252
# In situ date not found in satellite SST 2005-05-10 at 37.50465 -76.79252
# In situ date not found in satellite SST 2005-07-06 at 37.50465 -76.79252
# In situ date not found in satellite SST 2005-08-02 at 37.50465 -76.79252
# In situ date not found in satellite SST 2005-09-09 at 37.50465 -76.79252
# In situ date not found in satellite SST 2005-10-04 at 37.50465 -76.79252

# %%
wq_sst.ostia = wq_sst.ostia.astype('float')

# %%
# delete large data structures to save memory
# del ostia

# %% [markdown]
# ### Cleaning Output

# %% [markdown]
# Remove rows that don't have corresponding observations from any of the satellites.

# %%
anom_raw = anom_raw.reset_index()

# %%
wq_anom = anom_raw

# %%
wq_anom = wq_anom[(~wq_anom['anom_mur'].isnull()) | (~wq_anom['anom_geopolar'].isnull()) | \
                (~wq_anom['anom_ostia'].isnull())]

# %%
wq_sst = wq_sst[(~wq_sst['mur'].isnull()) | (~wq_sst['geopolar'].isnull())]

# %% [markdown]
# Sort values by date, latitude, and longitude

# %%
wq_anom = wq_anom.sort_values(['Station', 'SampleDate']).reset_index(drop=True)
wq_anom = wq_anom.round(decimals=4)

# %%
wq_sst = wq_sst.sort_values(['Station', 'SampleDate']).reset_index(drop=True)
wq_sst = wq_sst.round(decimals=4)

# %%
wq_anom
# Out:
#       Station SampleDate  Latitude  Longitude  anom_cbp  clim_geopolar  \
# 0       CB1.1 2003-01-15   39.5479   -76.0848   -2.9500         3.3992
# 1       CB1.1 2003-03-12   39.5479   -76.0848   -3.3500         4.4956
# 2       CB1.1 2003-04-09   39.5479   -76.0848   -5.6200        10.5856
# 3       CB1.1 2003-04-23   39.5479   -76.0848   -0.1200        10.5856
# 4       CB1.1 2003-05-07   39.5479   -76.0848   -0.4321        14.2421
# ...       ...        ...       ...        ...       ...            ...
# 14739   WT8.3 2023-08-08   38.8425   -76.5341    0.2083        26.4688
# 14740   WT8.3 2023-09-13   38.8425   -76.5341    4.0848        23.4165
# 14741   WT8.3 2023-10-17   38.8425   -76.5341   -0.5042        18.0821
# 14742   WT8.3 2023-11-16   38.8425   -76.5341    0.1381        12.5143
# 14743   WT8.3 2023-12-12   38.8425   -76.5341    0.8738         7.0552
#
#        sst_geopolar  anom_geopolar  clim_mur  sst_mur  anom_mur  clim_ostia  \
# 0              1.63        -1.7692    3.8769    2.076   -1.8009      3.6144
# 1              0.94        -3.5556    4.3557   -0.304   -4.6597      5.1571
# 2              7.52        -3.0656    9.7780    4.105   -5.6729     11.0994
# 3              9.19        -1.3956    9.7780    5.754   -4.0240     11.0994
# 4              9.67        -4.5721   16.0494    9.337   -6.7124     15.1550
# ...             ...            ...       ...      ...       ...         ...
# 14739         26.86         0.3912       NaN      NaN       NaN     26.8494
# 14740         26.58         3.1635       NaN      NaN       NaN     24.0041
# 14741         18.01        -0.0721       NaN      NaN       NaN     18.3747
# 14742         12.96         0.4457       NaN      NaN       NaN     12.8394
# 14743          8.37         1.3148       NaN      NaN       NaN      7.5323
#
#        sst_ostia  anom_ostia
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# ...          ...         ...
# 14739      26.69     -0.1594
# 14740      26.21      2.2059
# 14741      18.12     -0.2547
# 14742      12.79     -0.0494
# 14743       8.30      0.7676
#
# [14744 rows x 14 columns]

# %%
anom_raw
# Out:
#       Station SampleDate  Latitude  Longitude  anom_cbp  clim_geopolar  \
# 0       CB1.1 2003-01-15  39.54794  -76.08481    -2.950       3.399167
# 1       CB1.1 2005-01-13  39.54794  -76.08481     1.450       3.399167
# 2       CB1.1 2006-01-12  39.54794  -76.08481     0.950       3.399167
# 3       CB1.1 2007-01-12  39.54794  -76.08481     1.150       3.399167
# 4       CB1.1 2008-01-17  39.54794  -76.08481     0.650       3.399167
# ...       ...        ...       ...        ...       ...            ...
# 14739   WT8.3 2019-02-11  38.84250  -76.53410    -0.155       2.933501
# 14740   WT8.3 2020-02-13  38.84250  -76.53410     2.945       2.933501
# 14741   WT8.3 2021-02-08  38.84250  -76.53410    -0.755       2.933501
# 14742   WT8.3 2022-02-09  38.84250  -76.53410    -0.905       2.933501
# 14743   WT8.3 2023-02-16  38.84250  -76.53410     3.445       2.933501
#
#        sst_geopolar  anom_geopolar  clim_mur   sst_mur  anom_mur  clim_ostia  \
# 0          1.630005      -1.769162  3.876915  2.075989 -1.800926    3.614438
# 1          3.160004      -0.239164  3.876915  4.101013  0.224098    3.614438
# 2          3.910004       0.510836  3.876915  1.149994 -2.726921    3.614438
# 3          4.630005       1.230838  3.876915  6.183990  2.307076    3.614438
# 4          3.709991       0.310824  3.876915  3.701996 -0.174919    3.614438
# ...             ...            ...       ...       ...       ...         ...
# 14739      2.260010      -0.673491       NaN       NaN       NaN    2.861764
# 14740      3.980011       1.046510       NaN       NaN       NaN    2.861764
# 14741      3.220001       0.286500       NaN       NaN       NaN    2.861764
# 14742      2.670013      -0.263487       NaN       NaN       NaN    2.861764
# 14743      6.989990       4.056489       NaN       NaN       NaN    2.861764
#
#        sst_ostia  anom_ostia
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3       3.609985   -0.004452
# 4       3.739990    0.125553
# ...          ...         ...
# 14739   2.290009   -0.571756
# 14740   3.869995    1.008231
# 14741   3.440002    0.578238
# 14742   2.640015   -0.221750
# 14743   7.440002    4.578238
#
# [14744 rows x 14 columns]

# %% [markdown]
# Add a 0th row to each dataframe indicating column units

# %%
units_row = ['', '', 'degrees (epsg:4326)', 'degrees (epsg:4326)'] + ['deg C']*10
units_dict = dict(zip(wq_anom.columns, units_row))
units_df = pd.DataFrame(units_dict, index=[0])

wq_anom = pd.concat([units_df, wq_anom]).reset_index(drop=True)

# %%
units_row = ['', 'degrees (epsg:4326)', 'degrees (epsg:4326)', ''] + ['deg C']*4
units_dict = dict(zip(wq_sst.columns, units_row))
units_df = pd.DataFrame(units_dict, index=[0])

wq_sst = pd.concat([units_df, wq_sst]).reset_index(drop=True)

# %% [markdown]
# ### Save File

# %%
path = (
    REPO_ROOT / 'data/03_processed' / 
    'SSTanom_satellites_cbp_stations.csv'
    # 'SSTanom_satellites_cbp_stations_Feb13(datespecific).csv'
)
wq_anom.to_csv(path, index=False)

# %%
wq_anom
# Out:
#       Station           SampleDate             Latitude            Longitude  \
# 0                                   degrees (epsg:4326)  degrees (epsg:4326)
# 1       CB1.1  2003-01-15 00:00:00              39.5479             -76.0848
# 2       CB1.1  2003-03-12 00:00:00              39.5479             -76.0848
# 3       CB1.1  2003-04-09 00:00:00              39.5479             -76.0848
# 4       CB1.1  2003-04-23 00:00:00              39.5479             -76.0848
# ...       ...                  ...                  ...                  ...
# 14740   WT8.3  2023-08-08 00:00:00              38.8425             -76.5341
# 14741   WT8.3  2023-09-13 00:00:00              38.8425             -76.5341
# 14742   WT8.3  2023-10-17 00:00:00              38.8425             -76.5341
# 14743   WT8.3  2023-11-16 00:00:00              38.8425             -76.5341
# 14744   WT8.3  2023-12-12 00:00:00              38.8425             -76.5341
#
#       anom_cbp clim_geopolar sst_geopolar anom_geopolar clim_mur sst_mur  \
# 0        deg C         deg C        deg C         deg C    deg C   deg C
# 1        -2.95        3.3992         1.63       -1.7692   3.8769   2.076
# 2        -3.35        4.4956         0.94       -3.5556   4.3557  -0.304
# 3        -5.62       10.5856         7.52       -3.0656    9.778   4.105
# 4        -0.12       10.5856         9.19       -1.3956    9.778   5.754
# ...        ...           ...          ...           ...      ...     ...
# 14740   0.2083       26.4688        26.86        0.3912      NaN     NaN
# 14741   4.0848       23.4165        26.58        3.1635      NaN     NaN
# 14742  -0.5042       18.0821        18.01       -0.0721      NaN     NaN
# 14743   0.1381       12.5143        12.96        0.4457      NaN     NaN
# 14744   0.8738        7.0552         8.37        1.3148      NaN     NaN
#
#       anom_mur clim_ostia sst_ostia anom_ostia
# 0        deg C      deg C     deg C      deg C
# 1      -1.8009     3.6144       NaN        NaN
# 2      -4.6597     5.1571       NaN        NaN
# 3      -5.6729    11.0994       NaN        NaN
# 4       -4.024    11.0994       NaN        NaN
# ...        ...        ...       ...        ...
# 14740      NaN    26.8494     26.69    -0.1594
# 14741      NaN    24.0041     26.21     2.2059
# 14742      NaN    18.3747     18.12    -0.2547
# 14743      NaN    12.8394     12.79    -0.0494
# 14744      NaN     7.5323       8.3     0.7676
#
# [14745 rows x 14 columns]

# %%
path = (
    REPO_ROOT / 'data/03_processed' / 
    # 'SST_satellites_cbp_stations_Feb3(naivemonthly).csv'
    'SST_satellites_cbp_stations.csv'
)
wq_sst.to_csv(path, index=False)

# %%
wq_sst
# Out:
#            Station             Latitude            Longitude  \
# 0                   degrees (epsg:4326)  degrees (epsg:4326)
# 1      1AAUA001.39                 38.4               -77.32
# 2      1AAUA001.39                 38.4               -77.32
# 3      1AAUA001.39                 38.4               -77.32
# 4      1AAUA001.39                 38.4               -77.32
# ...            ...                  ...                  ...
# 37275    YRK031.24              37.5046             -76.7925
# 37276    YRK031.24              37.5046             -76.7925
# 37277    YRK031.24              37.5046             -76.7925
# 37278    YRK031.24              37.5046             -76.7925
# 37279    YRK031.24              37.5046             -76.7925
#
#                 SampleDate sst_cbp geopolar     mur  ostia
# 0                            deg C    deg C   deg C  deg C
# 1      2007-03-22 00:00:00     8.3      4.0     NaN   2.97
# 2      2007-06-18 00:00:00    26.2    21.97     NaN  20.51
# 3      2007-10-29 00:00:00    14.5    18.02     NaN  17.01
# 4      2007-12-10 00:00:00     5.2    10.75     NaN  11.37
# ...                    ...     ...      ...     ...    ...
# 37275  2008-07-22 00:00:00   29.46      NaN  27.757    NaN
# 37276  2008-08-22 00:00:00  26.455      NaN  26.091    NaN
# 37277  2008-09-17 00:00:00  25.105      NaN  23.483    NaN
# 37278  2008-10-16 00:00:00  21.134      NaN  21.225    NaN
# 37279  2008-11-20 00:00:00   9.925      NaN  10.874    NaN
#
# [37280 rows x 8 columns]
